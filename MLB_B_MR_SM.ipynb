# %% [markdown]
# # MLB Batters Multiple Linear Regression - Statsmodels

# %%
# import required modules
import pandas as pd
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
import pandas as pd
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_recall_fscore_support
import numpy as np
import statsmodels.api as sm

# %%
# load dataset
data = pd.read_csv('../Capstone/Data/MLB_Bpipeline1.csv', header=0)
data.shape
# Out:
# (35504, 49)

# %%
data=data.drop(['runs_good_plays', 'salary'], axis=1)
data=data.dropna()
data.reset_index(drop=True)
# Out:
#             age    mlb_ID   year_ID  stint_ID        PA         G       Inn  \
# 0     -0.482048 -0.645833 -1.899144 -0.271069  1.803485  1.514090  1.838357
# 1     -0.243918 -0.645833 -1.839840 -0.271069  1.834864  1.552709  1.833314
# 2     -0.005788 -0.645833 -1.780537 -0.271069  1.816933  1.572018  1.755907
# 3      0.232342 -0.645833 -1.721233 -0.271069  2.027621  1.668565  1.986811
# 4      0.470472 -0.645833 -1.661929 -0.271069  1.669003  1.359614  1.520399
# ...         ...       ...       ...       ...       ...       ...       ...
# 35336 -0.482048 -0.555187 -0.416551 -0.271069 -0.231672  0.123809 -0.122679
# 35337 -0.243918 -0.555187 -0.357247 -0.271069 -0.917529 -1.034758 -0.852886
# 35338 -0.005788 -0.555187 -0.297943 -0.271069 -1.011666 -1.169924 -1.007919
# 35339  0.232342 -0.555187 -0.238640 -0.271069 -0.518566 -0.455474 -0.351389
# 35340  0.470472 -0.555187 -0.179336 -0.271069 -0.904081 -0.976830 -0.904637
#
#        runs_bat   runs_br   runs_dp  ...  waa_win_perc_def  waa_win_perc_rep  \
# 0      3.000042  1.470890  1.648867  ...          0.554948         -1.692645
# 1      3.000042  2.722790  1.050723  ...          1.318595         -1.566606
# 2      3.000042 -0.116887 -0.091187  ...          0.201761         -1.516191
# 3      3.000042  3.000042  0.039317  ...         -0.762344         -1.969929
# 4      3.000042  3.000042 -2.396758  ...         -0.103698         -1.793475
# ...         ...       ...       ...  ...               ...               ...
# 35336 -0.656406  0.475476  1.159477  ...         -0.351883          0.223138
# 35337 -0.799984 -0.495511  0.158946  ...          0.278126          0.349176
# 35338 -0.497260  0.035784 -0.254317  ...         -0.132335          0.576045
# 35339 -0.635648 -0.629861  0.300325  ...         -0.542795          0.122307
# 35340 -0.060474 -0.239024  0.583084  ...          0.001304          0.298761
#
#        OPS_plus    TOB_lg     TB_lg   name_common  player_ID  team_ID  lg_ID  \
# 0      1.333030  1.700119  1.655725    Hank Aaron  aaronha01      MLN     NL
# 1      1.456844  1.793352  1.838187    Hank Aaron  aaronha01      MLN     NL
# 2      1.570087  1.848909  1.776025    Hank Aaron  aaronha01      MLN     NL
# 3      1.732124  1.882200  1.766711    Hank Aaron  aaronha01      MLN     NL
# 4      1.272600  1.606669  1.584471    Hank Aaron  aaronha01      MLN     NL
# ...         ...       ...       ...           ...        ...      ...    ...
# 35336 -0.162009 -0.233232 -0.244643  Paul Zuvella  zuvelpa01      ATL     NL
# 35337 -1.768644 -0.932326 -0.930573  Paul Zuvella  zuvelpa01      NYY     AL
# 35338 -1.466768 -1.015200 -0.993166  Paul Zuvella  zuvelpa01      NYY     AL
# 35339 -0.397373 -0.555822 -0.540034  Paul Zuvella  zuvelpa01      CLE     AL
# 35340  0.343162 -0.902117 -0.895383  Paul Zuvella  zuvelpa01      CLE     AL
#
#        pitcher
# 0            N
# 1            N
# 2            N
# 3            N
# 4            N
# ...        ...
# 35336        N
# 35337        N
# 35338        N
# 35339        N
# 35340        N
#
# [35341 rows x 47 columns]

# %%
features=['age', 'mlb_ID', 'year_ID',
       'stint_ID', 'PA', 'G', 'Inn', 'runs_bat', 'runs_br', 'runs_dp',
       'runs_field', 'runs_infield', 'runs_outfield', 'runs_catcher',
        'runs_defense', 'runs_position', 'runs_position_p',
       'runs_replacement', 'runs_above_rep', 'runs_above_avg',
       'runs_above_avg_off', 'runs_above_avg_def', 'WAA', 'WAA_off', 'WAA_def',
       'WAR_def', 'WAR_off', 'WAR_rep', 'teamRpG',
       'oppRpG', 'oppRpPA_rep', 'oppRpG_rep', 'pyth_exponent',
       'pyth_exponent_rep', 'waa_win_perc', 'waa_win_perc_off',
       'waa_win_perc_def', 'waa_win_perc_rep', 'OPS_plus', 'TOB_lg', 'TB_lg']
X=data[features]
y=data.WAR

# %%
model = sm.OLS(y, X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    WAR   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          9.131e+06
# Date:                Thu, 18 Jun 2020   Prob (F-statistic):                        0.00
# Time:                        23:53:11   Log-Likelihood:                      1.1464e+05
# No. Observations:               35341   AIC:                                 -2.292e+05
# Df Residuals:                   35302   BIC:                                 -2.289e+05
# Df Model:                          39
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# age                   -0.0001   5.67e-05     -2.245      0.025      -0.000   -1.61e-05
# mlb_ID             -6.584e-05   8.84e-05     -0.745      0.456      -0.000       0.000
# year_ID                0.0002   9.91e-05      1.744      0.081   -2.14e-05       0.000
# stint_ID            1.374e-05   6.17e-05      0.223      0.824      -0.000       0.000
# PA                     0.0077      0.002      4.500      0.000       0.004       0.011
# G                     -0.0001      0.000     -0.480      0.631      -0.001       0.000
# Inn                   -0.0050      0.001     -9.133      0.000      -0.006      -0.004
# runs_bat              -0.0026      0.001     -4.518      0.000      -0.004      -0.001
# runs_br               -0.0007      0.000     -6.684      0.000      -0.001      -0.000
# runs_dp             7.115e-06   7.12e-05      0.100      0.920      -0.000       0.000
# runs_field            -0.0005      0.000     -2.111      0.035      -0.001   -3.63e-05
# runs_infield          -0.0001   7.21e-05     -1.468      0.142      -0.000    3.55e-05
# runs_outfield         -0.0004    9.7e-05     -4.070      0.000      -0.001      -0.000
# runs_catcher       -8.773e-05      0.000     -0.694      0.488      -0.000       0.000
# runs_defense           0.0021      0.001      3.656      0.000       0.001       0.003
# runs_position         -0.0001      0.000     -0.368      0.713      -0.001       0.001
# runs_position_p    -7.623e-16   2.08e-17    -36.664      0.000   -8.03e-16   -7.22e-16
# runs_replacement      -0.3165      0.002   -157.128      0.000      -0.320      -0.313
# runs_above_rep         0.8185      0.003    294.561      0.000       0.813       0.824
# runs_above_avg        -0.6025      0.002   -242.455      0.000      -0.607      -0.598
# runs_above_avg_off     0.0040      0.002      2.588      0.010       0.001       0.007
# runs_above_avg_def    -0.0026      0.001     -2.392      0.017      -0.005      -0.000
# WAA                    0.7508      0.001    514.358      0.000       0.748       0.754
# WAA_off               -0.0806      0.003    -31.901      0.000      -0.086      -0.076
# WAA_def                0.0011      0.000      2.318      0.020       0.000       0.002
# WAR_def                0.0011      0.000      2.318      0.020       0.000       0.002
# WAR_off                0.1108      0.003     38.501      0.000       0.105       0.116
# WAR_rep                0.3282      0.002    171.935      0.000       0.324       0.332
# teamRpG               -0.0035      0.002     -1.881      0.060      -0.007       0.000
# oppRpG                -0.0382      0.011     -3.516      0.000      -0.060      -0.017
# oppRpPA_rep           -0.0002      0.000     -0.782      0.434      -0.001       0.000
# oppRpG_rep             0.0444      0.011      4.197      0.000       0.024       0.065
# pyth_exponent          0.0030      0.003      0.923      0.356      -0.003       0.009
# pyth_exponent_rep     -0.0059      0.003     -1.795      0.073      -0.012       0.001
# waa_win_perc           0.0004      0.000      1.033      0.302      -0.000       0.001
# waa_win_perc_off       0.0005      0.000      1.153      0.249      -0.000       0.001
# waa_win_perc_def   -8.432e-05      0.000     -0.421      0.674      -0.000       0.000
# waa_win_perc_rep      -0.0040      0.001     -3.906      0.000      -0.006      -0.002
# OPS_plus            4.041e-05      0.000      0.312      0.755      -0.000       0.000
# TOB_lg                -0.0058      0.001     -3.947      0.000      -0.009      -0.003
# TB_lg                  0.0003      0.001      0.360      0.719      -0.001       0.002
# ==============================================================================
# Omnibus:                    43160.250   Durbin-Watson:                   1.820
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         79311357.873
# Skew:                          -5.649   Prob(JB):                         0.00
# Kurtosis:                     234.803   Cond. No.                     1.46e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.85e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """
