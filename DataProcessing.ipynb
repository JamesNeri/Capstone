# %%
import requests

# %%
website_url=requests.get('https://www.hockey-reference.com/leagues/NHL_2020_skaters.html').text

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(website_url, 'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-root="/home/hr/build" data-version="klecko-" itemscope="" itemtype="https://schema.org/WebSite" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport"/>
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/202005291" rel="dns-prefetch"/>
# <!-- no:cookie fast load the css.           -->
# <script>function gup(n) {n = n.replace(/[\[]/, '\\[').replace(/[\]]/, '\\]'); var r = new RegExp('[\\?&]'+n+'=([^&#]*)'); var re = r.exec(location.search);   return re === null?'':decodeURIComponent(re[1].replace(/\+/g,' '));}; document.srdev = gup('srdev')</script>
# <link crossorigin="" href="https://d2p3bygnnzw9w3.cloudfront.net" rel="preconnect"/>
# <link crossorigin="" href="https://d9kjk42l7bfqz.cloudfront.net" rel="preconnect"/>
# ...

# %%
my_table=soup.find('table',{'class':'sortable stats_table'})

# %%
print(my_table)
