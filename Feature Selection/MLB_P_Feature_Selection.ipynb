# %%
# import required package for data handling
import pandas as pd
import numpy as np

# import required packages for splitting data
from sklearn import model_selection
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# import required packages for evaluating models
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_fscore_support

# import `linear regression` model
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn import datasets

# %%
data = pd.read_csv('../../Capstone/Data/MLB_Ppipeline1.csv', header=0)
data.head()
# Out:
#      name_common  year_ID team_ID lg_ID  xRA_sprp_adj  xRA_def_pitcher  \
# 0  David Aardsma     2004     SFG    NL     -0.235111        -0.168756
# 1  David Aardsma     2006     CHC    NL     -1.127094        -0.148680
# 2  David Aardsma     2007     CHW    AL     -0.727446        -0.492837
# 3  David Aardsma     2008     BOS    AL     -1.054034         0.220572
# 4  David Aardsma     2009     SEA    AL     -1.573630         1.107136
#
#    RS_def_total  RpO_replacement   teamRpG       age  ...  pyth_exponent  \
# 0     -1.131299         0.334052  0.537732 -1.639536  ...       0.334768
# 1     -0.273196         0.781469  1.046313 -0.950150  ...       0.414066
# 2     -1.600033         1.172959  1.026056 -0.643021  ...       0.584775
# 3      0.515466         0.781469  0.623642 -0.357360  ...       0.357401
# 4      1.946466         1.005178  0.867454 -0.090951  ...       0.300854
#
#    waa_win_perc       WAA   WAA_adj  oppRpG_rep  pyth_exponent_rep  \
# 0     -0.132935 -0.108598 -0.223338    0.011131           0.231446
# 1      0.243431  0.347895 -0.776132    0.491663           0.767568
# 2     -0.162888 -0.461935 -1.008741    0.561573           0.790787
# 3     -0.085625 -0.723615 -0.466037    0.142303           0.361738
# 4      0.311221  0.745809  1.983143    0.339647           0.584389
#
#    waa_win_perc_rep   WAR_rep  ERA_plus     ER_lg
# 0          1.102892 -1.152259 -0.556962 -1.021506
# 1          0.948991 -0.023940  0.350133  0.236178
# 2          0.652706 -0.321927 -0.399802 -0.184497
# 3          0.882688  0.088441 -0.204403  0.155605
# 4          0.932296  0.525550  1.194354  0.434936
#
# [5 rows x 38 columns]

# %%
data.dtypes
# Out:
# name_common               object
# year_ID                    int64
# team_ID                   object
# lg_ID                     object
# xRA_sprp_adj             float64
# xRA_def_pitcher          float64
# RS_def_total             float64
# RpO_replacement          float64
# teamRpG                  float64
# age                      float64
# G                        float64
# GS                       float64
# IPouts                   float64
# IPouts_start             float64
# IPouts_relief            float64
# RA                       float64
# xRA                      float64
# PPF                      float64
# PPF_custom               float64
# xRA_final                float64
# BIP                      float64
# BIP_perc                 float64
# runs_above_avg           float64
# runs_above_avg_adj       float64
# runs_above_rep           float64
# GR_leverage_index_avg    float64
# WAR                      float64
# oppRpG                   float64
# pyth_exponent            float64
# waa_win_perc             float64
# WAA                      float64
# WAA_adj                  float64
# oppRpG_rep               float64
# pyth_exponent_rep        float64
# waa_win_perc_rep         float64
# WAR_rep                  float64
# ERA_plus                 float64
# ER_lg                    float64
# dtype: object

# %%
data.columns
# Out:
# Index(['name_common', 'year_ID', 'team_ID', 'lg_ID', 'xRA_sprp_adj',
#        'xRA_def_pitcher', 'RS_def_total', 'RpO_replacement', 'teamRpG', 'age',
#        'G', 'GS', 'IPouts', 'IPouts_start', 'IPouts_relief', 'RA', 'xRA',
#        'PPF', 'PPF_custom', 'xRA_final', 'BIP', 'BIP_perc', 'runs_above_avg',
#        'runs_above_avg_adj', 'runs_above_rep', 'GR_leverage_index_avg', 'WAR',
#        'oppRpG', 'pyth_exponent', 'waa_win_perc', 'WAA', 'WAA_adj',
#        'oppRpG_rep', 'pyth_exponent_rep', 'waa_win_perc_rep', 'WAR_rep',
#        'ERA_plus', 'ER_lg'],
#       dtype='object')

# %%
list(data.columns)[26]
# Out:
# 'WAR'

# %%
dataframe = data
array = dataframe.values
X = dataframe[['xRA_sprp_adj',
       'xRA_def_pitcher', 'RS_def_total', 'RpO_replacement', 'teamRpG', 'age',
       'G', 'GS', 'IPouts', 'IPouts_start', 'IPouts_relief', 'RA', 'xRA',
       'PPF', 'PPF_custom', 'xRA_final', 'BIP', 'BIP_perc', 'runs_above_avg',
       'runs_above_avg_adj', 'runs_above_rep', 'GR_leverage_index_avg',
       'oppRpG', 'pyth_exponent', 'waa_win_perc', 'WAA', 'WAA_adj',
       'oppRpG_rep', 'pyth_exponent_rep', 'waa_win_perc_rep', 'WAR_rep',
       'ERA_plus', 'ER_lg']].to_numpy()
Y = array[:,26] #target

# create a base classifier used to evaluate a subset of attributes
model = LinearRegression()

# create the RFE model and select 5 attributes
rfe = RFE(model, 10)
fit = rfe.fit(X, Y)

# summarize the selection of the attributes for Y1
print("Num Features: %s" % (fit.n_features_))
print("Selected Features: %s" % (fit.support_))
print("Feature Ranking: %s" % (fit.ranking_))

X_reduced = rfe.transform(X)
# Out:
# Num Features: 10
# Selected Features: [False False False False False False False False  True False False False
#   True False False  True False False  True  True  True False False False
#  False  True  True False False False  True False  True]
# Feature Ranking: [16 20 14  3  2 23 15 11  1 13 17  4  1 18 19  1  8 21  1  1  1 12  5  6
#   7  1  1  9 10 24  1 22  1]

# %% [markdown]
# **Top ten columns:**
# 'IPouts',
# 'xRA',
# 'xRA_final',
# 'runs_above_avg',
# 'runs_above_avg_adj',
# 'runs_above_rep',
# 'WAA',
# 'WAA_adj',
# 'WAR_rep',
# 'ER_lg'
