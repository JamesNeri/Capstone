# %% [markdown]
# # Initial Data Cleaning and EDA

# %%
# data handling
import sweetviz as sv
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt
from pandas import DataFrame
# %matplotlib inline

# splitting data
from sklearn import model_selection
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# evaluating models
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_fscore_support
from scipy.stats import boxcox
from scipy import stats

# `logistic regression` model
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv('../../Capstone/Data/MLB_Pitching_Data.csv')

# %%
data.dtypes
# Out:
# name_common               object
# age                      float64
# mlb_ID                   float64
# player_ID                 object
# year_ID                    int64
# team_ID                   object
# stint_ID                   int64
# lg_ID                     object
# G                          int64
# GS                         int64
# IPouts                     int64
# IPouts_start             float64
# IPouts_relief            float64
# RA                         int64
# xRA                      float64
# xRA_sprp_adj             float64
# xRA_def_pitcher          float64
# PPF                        int64
# PPF_custom               float64
# xRA_final                float64
# BIP                        int64
# BIP_perc                 float64
# RS_def_total             float64
# runs_above_avg           float64
# runs_above_avg_adj       float64
# runs_above_rep           float64
# RpO_replacement          float64
# GR_leverage_index_avg    float64
# ...

# %%
data.drop(data[data['year_ID'] < 1960].index, inplace = True)

# %%
data.reset_index(drop=True)
# Out:
#          name_common   age    mlb_ID  player_ID  year_ID team_ID  stint_ID  \
# 0      David Aardsma  22.0  430911.0  aardsda01     2004     SFG         1
# 1      David Aardsma  24.0  430911.0  aardsda01     2006     CHC         1
# 2      David Aardsma  25.0  430911.0  aardsda01     2007     CHW         1
# 3      David Aardsma  26.0  430911.0  aardsda01     2008     BOS         1
# 4      David Aardsma  27.0  430911.0  aardsda01     2009     SEA         1
# ...              ...   ...       ...        ...      ...     ...       ...
# 31705    Joel Zumaya  24.0  451491.0  zumayjo01     2009     DET         1
# 31706    Joel Zumaya  25.0  451491.0  zumayjo01     2010     DET         1
# 31707      Tony Zych  24.0  543964.0   zychto01     2015     SEA         1
# 31708      Tony Zych  25.0  543964.0   zychto01     2016     SEA         1
# 31709      Tony Zych  26.0  543964.0   zychto01     2017     SEA         1
#
# ...

# %%
data.isna().any()
# Out:
# name_common              False
# age                      False
# mlb_ID                   False
# player_ID                False
# year_ID                  False
# team_ID                  False
# stint_ID                 False
# lg_ID                    False
# G                        False
# GS                       False
# IPouts                   False
# IPouts_start              True
# IPouts_relief             True
# RA                       False
# xRA                      False
# xRA_sprp_adj              True
# xRA_def_pitcher          False
# PPF                      False
# PPF_custom                True
# xRA_final                 True
# BIP                      False
# BIP_perc                 False
# RS_def_total             False
# runs_above_avg            True
# runs_above_avg_adj        True
# runs_above_rep            True
# RpO_replacement          False
# GR_leverage_index_avg    False
# WAR                       True
# salary                    True
# ...

# %%
data = data.fillna(0)

# %%
data.isna().any()
# Out:
# name_common              False
# age                      False
# mlb_ID                   False
# player_ID                False
# year_ID                  False
# team_ID                  False
# stint_ID                 False
# lg_ID                    False
# G                        False
# GS                       False
# IPouts                   False
# IPouts_start             False
# IPouts_relief            False
# RA                       False
# xRA                      False
# xRA_sprp_adj             False
# xRA_def_pitcher          False
# PPF                      False
# PPF_custom               False
# xRA_final                False
# BIP                      False
# BIP_perc                 False
# RS_def_total             False
# runs_above_avg           False
# runs_above_avg_adj       False
# runs_above_rep           False
# RpO_replacement          False
# GR_leverage_index_avg    False
# WAR                      False
# salary                   False
# ...

# %%
data.to_csv('../../Capstone/Data/FirstClean_MLB_Pitching_Data.csv', index=0)

# %%
my_report = sv.analyze(data, target_feat='WAR')
my_report.show_html('../../Capstone/EDA HTML files/PitchingEDA.html')
# Out:
# :FEATURES DONE:                    |█████████████████████| [100%]   00:27  -> (00:00 left)
# :PAIRWISE DONE:                    |█████████████████████| [100%]   00:02  -> (00:00 left)
# Creating Associations graph... DONE!
